# %%
import geopandas as gpd

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world.plot(color='grey',linewidth=0.5,edgecolor='white', figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
import os
data_path="./data/"

# %% [markdown]
# The following data file was downloaded from [Natural Earth](https://www.naturalearthdata.com), via the list of links to their files on AWS: https://gist.github.com/DanielJWood/b71237cc200831acf8e637c05ce2c375#file-natural_earth_s3_links-md
# I simply copied the files into a "data" directory in this github repository.

# %%
cities = gpd.read_file(os.path.join(data_path,'ne_10m_populated_places.shp'))
cities.head()
# Out:
#    SCALERANK  NATSCALE  LABELRANK       FEATURECLA                    NAME  \
# 0         10         1          8  Admin-1 capital  Colonia del Sacramento
# 1         10         1          8  Admin-1 capital                Trinidad
# 2         10         1          8  Admin-1 capital             Fray Bentos
# 3         10         1          8  Admin-1 capital               Canelones
# 4         10         1          8  Admin-1 capital                 Florida
#
#   NAMEPAR NAMEALT  DIFFASCII               NAMEASCII  ADM0CAP  ...  \
# 0    None    None          0  Colonia del Sacramento      0.0  ...
# 1    None    None          0                Trinidad      0.0  ...
# 2    None    None          0             Fray Bentos      0.0  ...
# 3    None    None          0               Canelones      0.0  ...
# 4    None    None          0                 Florida      0.0  ...
#
#           name_ja     name_ko                 name_nl                 name_pl  \
# ...

# %%
cities.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
base = world.plot(color='grey', linewidth=0.5, edgecolor='white', figsize=(15,10))
cities.plot(ax=base, color='orange', markersize=5)
base.set_axis_off()
